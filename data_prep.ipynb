# %%
import pandas as pd
import pandas_profiling

# %%
# Loading all the datasets
campaign_data = pd.read_csv("data/campaign_data.csv")
coupon_item_mapping = pd.read_csv("data/coupon_item_mapping.csv")
customer_demographics = pd.read_csv("data/customer_demographics.csv")
customer_transaction_data = pd.read_csv("data/customer_transaction_data.csv")
item_data = pd.read_csv("data/item_data.csv")
train = pd.read_csv("data/train.csv")
test = pd.read_csv("data/test.csv")

# %%
# duplicating original data for transformations
datasets_dict = {}
datasets_dict['campaign_data'] = campaign_data
datasets_dict['coupon_item_mapping'] = coupon_item_mapping
datasets_dict['customer_demographics'] = customer_demographics
datasets_dict['customer_transaction_data'] = customer_transaction_data
datasets_dict['item_data'] = item_data
datasets_dict['train'] = train
datasets_dict['test'] = test
# del(campaign_data,coupon_item_mapping,customer_demographics,customer_transaction_data,item_data,train,test)

# %%
# for k in datasets_dict.keys():
#     print("Dataset {}".format(k))
#     print("Dataset Shape: {}".format(datasets_dict[k].shape))
#     print("Nulls: {}".format(datasets_dict[k].isna().sum().any()))
#     print("*"*50)
datasets_dict['customer_demographics'].profile_report()
# Out:
#                 <iframe
#                     width="100%"
#                     height="800px"
#                     srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;utf-8&quot;&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;
#     &lt;meta name=&quot;description&quot; content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;
#     &lt;meta name=&quot;author&quot; content=&quot;Jos Polfliet, Simon Brugman and the open source community.&quot;&gt;
#     &lt;meta name=&quot;generator&quot; content=&quot;Pandas Profiling 2.3.0&quot; /&gt;
#     &lt;meta name=&quot;url&quot; content=&quot;https://github.com/pandas-profiling/pandas-profiling&quot;&gt;
#
#     &lt;title&gt;Pandas Profiling Report&lt;/title&gt;
#
# &lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
# ...

# %% [markdown]
# ## Data Set Schema Definition
# <img src='dataset-schema.png' style='height:400px'/>

# %%
# datasets_dict['train'].merge(datasets_dict['campaign_data'],on='campaign_id',how='left').merge(datasets_dict['coupon_item_mapping'].merge(datasets_dict['item_data'],on='item_id',how='left'))\
# .merge(datasets_dict['customer_demographics'],on='customer_id',how='left').merge(datasets_dict['customer_transaction_data'],on='customer_id',how='left')

a = set(datasets_dict['train']['coupon_id'].unique())
len(a)
# Out:
# 866
